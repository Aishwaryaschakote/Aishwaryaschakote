# %% [markdown]
# <a href="https://colab.research.google.com/github/Aishwaryaschakote/Aishwaryaschakote/blob/main/AICC_day_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # starting with AICC

# %%
name= input("enter your name:")
print("Hello", name)
# Out:
# enter your name:Aishwarya
# Hello Aishwarya

# %%
age= int(input("enter your age:"))
print("your age is", age)
if age>=18:
  print("you are eligible to vote")
else:
  print("you are not eligible to vote")
# Out:
# enter your age:22
# your age is 22
# you are eligible to vote

# %%
  password = input("Enter your password: ")
  if password == "123":
    print("Password is correct")

  else:
    print("Wrong password")
    fev_food = input("Enter your favorite food: ")
    fev_color = input("Enter your favorite color: ")
    if(fev_food == "pizza" and fev_color == "red"):
      print("permission granted")
    else:
      print("sorry..!\ntry later")
# Out:
# Enter your password: 45
# Wrong password
# Enter your favorite food: fe
# Enter your favorite color: fe
# sorry..!
# try later

# %% [markdown]
# # day 2

# %%
# loops
for i in range(1,6):
  print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
for i in range(0,11,2):
  print(i)
# Out:
# 0
# 2
# 4
# 6
# 8
# 10

# %%
for i in range(0,11):
  print("aishwarya")
# Out:
# aishwarya
# aishwarya
# aishwarya
# aishwarya
# aishwarya
# aishwarya
# aishwarya
# aishwarya
# aishwarya
# aishwarya
# aishwarya

# %%
fruit=['app','mango', 'cherry']
for i in fruit:
  print(fruit)
# Out:
# ['app', 'mango', 'cherry']
# ['app', 'mango', 'cherry']
# ['app', 'mango', 'cherry']

# %%
fruit=['apple','mango', 'cherry']
for i in fruit:
  print(i)
# Out:
# app
# mango
# cherry

# %%
i=1
while i<=5:
  print(i)
  i+=1
# Out:
# 1
# 2
# 3
# 4
# 5
