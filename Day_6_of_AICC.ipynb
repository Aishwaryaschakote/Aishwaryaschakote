# %% [markdown]
# <a href="https://colab.research.google.com/github/Aishwaryaschakote/Aishwaryaschakote/blob/main/Day_6_of_AICC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #pandas library

# %%
import pandas as pd

# %%
marks = pd.Series([57,45,35,67])
print (marks)
# Out:
# 0    57
# 1    45
# 2    35
# 3    67
# dtype: int64
